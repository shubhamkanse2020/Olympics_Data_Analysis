# %% [markdown]
# # Import Libraries

# %%
# Numpy -> to perform the mathematical operation
import numpy as np
#  Pandas -> data manipulation tool
import pandas as pd
# matplotlib-> data visualisation tool
import matplotlib.pyplot as plt
 # SEaborn -> data visualisation tool
import seaborn as sns
import re

# %% [markdown]
# # Reading the Dataset

# %%
athlete =pd.read_csv("/content/athlete_events (1).csv",engine = "python",error_bad_lines=False)
noc =pd.read_csv("/content/noc_regions (1).csv")
# Out:
# <ipython-input-13-1bb6424a4e18>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   athlete =pd.read_csv("/content/athlete_events (1).csv",engine = "python",error_bad_lines=False)

# %% [markdown]
# # Creating the copy of the dataframe

# %%
ath=athlete.copy()
nat=noc.copy()

# %% [markdown]
# # Data Exception

# %%
ath.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
ath.tail()
# Out:
#           ID                                   Name Sex   Age  Height  Weight  \
# 27590  14312  Svetlana Sergeyevna Boyarkina-Zhurova   F  34.0   176.0    64.0
# 27591  14313         Nataliya Sergeyevna Boyarskaya   F  25.0   167.0    67.0
# 27592  14313         Nataliya Sergeyevna Boyarskaya   F  25.0   167.0    67.0
# 27593  14314         Klavdiya Sergeyevna Boyarskikh   F  24.0   159.0    60.0
# 27594  14314         Klavdiya Sergeyevna Boyarskikh   F  24.0   159.0    60.0
#
#                Team  NOC        Games  Year  Season       City  \
# 27590        Russia  RUS  2006 Winter  2006  Winter     Torino
# 27591        Russia  RUS  2008 Summer  2008  Summer    Beijing
# 27592        Russia  RUS  2008 Summer  2008  Summer    Beijing
# 27593  Soviet Union  URS  1964 Winter  1964  Winter  Innsbruck
# 27594  Soviet Union  URS  1964 Winter  1964  Winter  Innsbruck
#
#                       Sport                                       Event Medal
# ...

# %%
ath.shape
# Out:
# (27595, 15)

# %%
nat.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
ath.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27595 entries, 0 to 27594
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      27595 non-null  int64
#  1   Name    27595 non-null  object
#  2   Sex     27595 non-null  object
#  3   Age     26512 non-null  float64
#  4   Height  21228 non-null  float64
#  5   Weight  20986 non-null  float64
#  6   Team    27595 non-null  object
#  7   NOC     27595 non-null  object
#  8   Games   27595 non-null  object
#  9   Year    27595 non-null  int64
#  10  Season  27595 non-null  object
#  11  City    27595 non-null  object
#  12  Sport   27595 non-null  object
#  13  Event   27595 non-null  object
#  14  Medal   3733 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 3.2+ MB

# %%
ath.describe()
# Out:
#                  ID           Age        Height        Weight          Year
# count  27595.000000  26512.000000  21228.000000  20986.000000  27595.000000
# mean    7366.005327     25.567215    175.636612     71.027495   1978.564160
# std     4119.154286      6.389783     10.360985     14.315018     29.619638
# min        1.000000     12.000000    132.000000     32.000000   1896.000000
# 25%     3876.000000     21.000000    169.000000     61.000000   1960.000000
# 50%     7472.000000     24.000000    175.000000     70.000000   1988.000000
# 75%    10918.000000     28.000000    183.000000     79.000000   2002.000000
# max    14314.000000     84.000000    221.000000    214.000000   2016.000000

# %%
ath.isnull().sum()
# Out:
# ID            0
# Name          0
# Sex           0
# Age        1083
# Height     6367
# Weight     6609
# Team          0
# NOC           0
# Games         0
# Year          0
# Season        0
# City          0
# Sport         0
# Event         0
# Medal     23862
# dtype: int64

# %% [markdown]
# # Data Cleaing and Data Manipulation
# 1. Add a new column 'region' to the DataFrame. and the region column should have the regions according to the element in the Noc columns of the 'nat' DataFrame

# %%
at=ath.merge(nat,how='left',on="NOC")
at.drop(['NOC',"notes"],axis=1,inplace=True)

# %%
at.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#          Games  Year  Season       City          Sport  \
# 0  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  2012 Summer  2012  Summer     London           Judo
# 2  1920 Summer  1920  Summer  Antwerpen       Football
# 3  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region
# 0       Basketball Men's Basketball   NaN        China
# 1      Judo Men's Extra-Lightweight   NaN        China
# ...

# %%
region_col=ath['NOC'].map(nat.set_index('NOC')['region'])
ath.insert(7,'region',region_col)

# %%
ath
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team       region  NOC        Games  Year  Season  \
# 0                China        China  CHN  1992 Summer  1992  Summer
# ...

# %%
ath.shape
# Out:
# (271116, 16)

# %%
ath.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland
#
#         region  NOC        Games  Year  Season            City        Sport  \
# 271111  Poland  POL  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  Poland  POL  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  Poland  POL  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  Poland  POL  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  Poland  POL  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# ...

# %% [markdown]
# # Drop the column "NOC" from the DataFrame"ath"

# %%
ath.drop("NOC",inplace = True,axis=1)

# %%
ath
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team       region        Games  Year  Season  \
# 0                China        China  1992 Summer  1992  Summer
# ...

# %% [markdown]
# 3 Handing the null values in the columns-"Age","height"&"weight" by the mean of the respective columns

# %%
ath[ath.Age.isnull()].head()
# Out:
#       ID                   Name Sex  Age  Height  Weight      Team    region  \
# 147   54  Mohamed Jamshid Abadi   M  NaN     NaN     NaN      Iran      Iran
# 152   58       Georgi Abadzhiev   M  NaN     NaN     NaN  Bulgaria  Bulgaria
# 153   58       Georgi Abadzhiev   M  NaN     NaN     NaN  Bulgaria  Bulgaria
# 162   66        Mohamed Abakkar   M  NaN   156.0    48.0     Sudan     Sudan
# 212  102      Sayed Fahmy Abaza   M  NaN     NaN     NaN     Egypt     Egypt
#
#            Games  Year  Season       City     Sport  \
# 147  1948 Summer  1948  Summer     London    Boxing
# 152  1924 Summer  1924  Summer      Paris   Cycling
# 153  1924 Summer  1924  Summer      Paris   Cycling
# 162  1972 Summer  1972  Summer     Munich    Boxing
# 212  1920 Summer  1920  Summer  Antwerpen  Football
#
#                                    Event Medal
# 147             Boxing Men's Heavyweight   NaN
# 152  Cycling Men's Road Race, Individual   NaN
# ...

# %%
ath['Age'].fillna(ath.Age.mean(),inplace=True)
ath['Height'].fillna(ath.Age.mean(),inplace=True)
ath['Weight'].fillna(ath.Age.mean(),inplace=True)

# %%
ath.iloc[[147]]
# Out:
#      ID                   Name Sex        Age     Height     Weight  Team  \
# 147  54  Mohamed Jamshid Abadi   M  25.556898  25.556898  25.556898  Iran
#
#     region        Games  Year  Season    City   Sport  \
# 147   Iran  1948 Summer  1948  Summer  London  Boxing
#
#                         Event Medal
# 147  Boxing Men's Heavyweight   NaN

# %%
ath.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age            0
# Height         0
# Weight         0
# Team           0
# region       370
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %% [markdown]
# 4 list out all the values of the region column where the values are null

# %%
nat.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
nat.where(nat['region']=='Singapore')
# Out:
#      NOC region notes
# 0    NaN    NaN   NaN
# 1    NaN    NaN   NaN
# 2    NaN    NaN   NaN
# 3    NaN    NaN   NaN
# 4    NaN    NaN   NaN
# ..   ...    ...   ...
# 225  NaN    NaN   NaN
# 226  NaN    NaN   NaN
# 227  NaN    NaN   NaN
# 228  NaN    NaN   NaN
# 229  NaN    NaN   NaN
#
# [230 rows x 3 columns]

# %% [markdown]
#  5 Handiihg the null values in the column 'Medals'

# %%
ath['Medal'].unique()
# Out:
# 3

# %%
ath['Medal'].nunique()
# Out:
# 3

# %%
ath['Medal'].value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
# Replace
# NaN with 0
# Gold with 1
# Silver with 2
 # Bronze with 3
ath.Medal.replace([np.nan],[0],inplace=True)

# %%
ath['Medal'].value_counts()
# Out:
# 0.0    231333
# 1.0     13372
# 3.0     13295
# 2.0     13116
# Name: Medal, dtype: int64

# %%
ath.Medal=ath.Medal.astype(int)

# %%
ath.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     271116 non-null  float64
#  4   Height  271116 non-null  float64
#  5   Weight  271116 non-null  float64
#  6   Team    271116 non-null  object
#  7   region  270746 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   271116 non-null  int64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 31.0+ MB

# %%
ath.isnull().sum()
# Out:
# ID          0
# Name        0
# Sex         0
# Age         0
# Height      0
# Weight      0
# Team        0
# region    370
# Games       0
# Year        0
# Season      0
# City        0
# Sport       0
# Event       0
# Medal       0
# dtype: int64

# %% [markdown]
# 6 dropping off the un-wanted/irrevant data

# %%
# Columns to be drop off-

ath.drop(["region","Games"],axis=1,inplace=True)

# %%
ath.head()
# Out:
#    ID                      Name Sex   Age      Height     Weight  \
# 0   1                 A Dijiang   M  24.0  180.000000  80.000000
# 1   2                  A Lamusi   M  23.0  170.000000  60.000000
# 2   3       Gunnar Nielsen Aaby   M  24.0   25.556898  25.556898
# 3   4      Edgar Lindenau Aabye   M  34.0   25.556898  25.556898
# 4   5  Christine Jacoba Aaftink   F  21.0  185.000000  82.000000
#
#              Team  Year  Season       City          Sport  \
# 0           China  1992  Summer  Barcelona     Basketball
# 1           China  2012  Summer     London           Judo
# 2         Denmark  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  1988  Winter    Calgary  Speed Skating
#
#                               Event  Medal
# 0       Basketball Men's Basketball      0
# 1      Judo Men's Extra-Lightweight      0
# 2           Football Men's Football      0
# 3       Tug-Of-War Men's Tug-Of-War      1
# ...

# %% [markdown]
# 7 Remove the unwanted phrases from the
# "Event" column

# %%
for i,j in zip(ath.Sport,range(len(ath.Event))):
 ath.Event[j]= re.sub(f"{i}+'","",ath.Event[j])
# Out:
# <ipython-input-60-4e7de4efa655>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ath.Event[j]= re.sub(f"{i}+' '","",ath.Event[j])

# %%
ath.head(2)
# Out:
#    ID       Name Sex   Age  Height  Weight   Team  Year  Season       City  \
# 0   1  A Dijiang   M  24.0   180.0    80.0  China  1992  Summer  Barcelona
# 1   2   A Lamusi   M  23.0   170.0    60.0  China  2012  Summer     London
#
#         Sport                         Event  Medal
# 0  Basketball   Basketball Men's Basketball      0
# 1        Judo  Judo Men's Extra-Lightweight      0

# %%
re.sub("Basketball","",ath.Event[0])
# Out:
# " Men's "

# %%
for i,j in zip(ath.Sport,range(len(ath.Event))):
 ath.Event[j]= re.sub(f"{i}\s","",ath.Event[j])
# Out:
# <ipython-input-65-03d24817c64c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ath.Event[j]= re.sub(f"{i}\s","",ath.Event[j])
